# %% [markdown]
# ### Workflow for the 50 Planes Mesh
#   1. In blender we load planes_sorted50.txt (the indices of these are -2 of the original indices e.g. pacakge_2.par -> Plane.000)
#   2. Select individually the plane we want to use for slicing and scale
#   3. Once we have selected the planes, nudge them against normal direction (normal should be negative in x)
#   4. Write them to a file in order according to their plane indices
#   5. Make a mesh case folder
#   6. The case folder should contain a planes files with all the selected planes and one final plane that can farther to the positive x than all other planes
#   7. The file.prj for the mesh folder should contain all the package_*.par files of the chosen planes
#   8.

# %%
import numpy as np

# %%
a = np.array([-2.11931, -2.16788, 0.383654])
b = np.array([-2.06736, -2.21556, 0.381414])

# %%
# %ls CASE_090_772/params/
# Out:
# package_10.par  package_20.par  package_2.par   package_39.par  package_48.par
# package_11.par  package_21.par  package_30.par  package_3.par   package_49.par
# package_12.par  package_22.par  package_31.par  package_40.par  package_4.par
# package_13.par  package_23.par  package_32.par  package_41.par  package_50.par
# package_14.par  package_24.par  package_33.par  package_42.par  package_5.par
# package_15.par  package_25.par  package_34.par  package_43.par  package_6.par
# package_16.par  package_26.par  package_35.par  package_44.par  package_7.par
# package_17.par  package_27.par  package_36.par  package_45.par  package_8.par
# package_18.par  package_28.par  package_37.par  package_46.par  package_9.par
# package_19.par  package_29.par  package_38.par  package_47.par

# %%
import numpy as np

def point_normal_form(a, b, c, d):
    """
    Compute the point-normal form of a plane from its general equation.
    
    ax + by + cz + d = 0 -> point-normal form: (x - x0, y - y0, z - z0) · (a, b, c) = 0
    
    Parameters:
        a, b, c, d (float): Coefficients of the plane equation.
    
    Returns:
        tuple: Normal vector (a, b, c) and a point (x0, y0, z0) on the plane.
    """
    # Normal vector
    normal_vector = np.array([a, b, c], dtype=float)

    # Finding a point on the plane
    # We set two variables to 0 and solve for the third if possible
    if a != 0:
        point_on_plane = np.array([-d / a, 0, 0])
    elif b != 0:
        point_on_plane = np.array([0, -d / b, 0])
    elif c != 0:
        point_on_plane = np.array([0, 0, -d / c])
    else:
        raise ValueError("Invalid plane equation with a (0, 0, 0) normal vector")
    return normal_vector, point_on_plane

# %%
import glob
import re

def natural_sort_key(filename):
    numbers = re.findall(r'\d+', filename)

    return [int(num) for num in numbers]

files = glob.glob("./CASE_090_772/params/*.par")

sorted_filenames = sorted(files, key=natural_sort_key)
print("Original list:", files)
print("Naturally sorted list:", sorted_filenames)

for file in sorted_filenames:
    with open(file, "r") as f:
        lines = f.readlines()
        clean = lines[1].replace("'","")
        print(f"clean = {clean}")
        eq = clean.split()
        print(eq)
        a = float(eq[1]) 
        b = float(eq[2]) 
        c = float(eq[3]) 
        d = float(eq[4]) 
        print(f"{a}x + {b}y + {c}z + {d} = 0")
        normal, point = point_normal_form(a, b, c, d)
        if normal[0] > 0:
            normal = -1. * normal
        print(f"Point normal form: {point[0]} {point[1]} {point[2]} {normal[0]} {normal[1]} {normal[2]}")
        with open("planes_sorted50.txt", "a") as output_file:
            output_file.write(f"{point[0]} {point[1]} {point[2]} {normal[0]} {normal[1]} {normal[2]}\n")
# Out:
# Original list: ['./CASE_090_772/params/package_12.par', './CASE_090_772/params/package_31.par', './CASE_090_772/params/package_39.par', './CASE_090_772/params/package_42.par', './CASE_090_772/params/package_45.par', './CASE_090_772/params/package_26.par', './CASE_090_772/params/package_24.par', './CASE_090_772/params/package_3.par', './CASE_090_772/params/package_15.par', './CASE_090_772/params/package_43.par', './CASE_090_772/params/package_23.par', './CASE_090_772/params/package_11.par', './CASE_090_772/params/package_13.par', './CASE_090_772/params/package_14.par', './CASE_090_772/params/package_5.par', './CASE_090_772/params/package_48.par', './CASE_090_772/params/package_4.par', './CASE_090_772/params/package_25.par', './CASE_090_772/params/package_49.par', './CASE_090_772/params/package_37.par', './CASE_090_772/params/package_18.par', './CASE_090_772/params/package_44.par', './CASE_090_772/params/package_28.par', './CASE_090_772/params/package_22.par', './CASE_090_772/params/package_8.par', './CASE_090_772/params/package_40.par', './CASE_090_772/params/package_21.par', './CASE_090_772/params/package_41.par', './CASE_090_772/params/package_10.par', './CASE_090_772/params/package_50.par', './CASE_090_772/params/package_30.par', './CASE_090_772/params/package_27.par', './CASE_090_772/params/package_32.par', './CASE_090_772/params/package_6.par', './CASE_090_772/params/package_29.par', './CASE_090_772/params/package_20.par', './CASE_090_772/params/package_34.par', './CASE_090_772/params/package_9.par', './CASE_090_772/params/package_7.par', './CASE_090_772/params/package_2.par', './CASE_090_772/params/package_19.par', './CASE_090_772/params/package_38.par', './CASE_090_772/params/package_36.par', './CASE_090_772/params/package_33.par', './CASE_090_772/params/package_17.par', './CASE_090_772/params/package_35.par', './CASE_090_772/params/package_46.par', './CASE_090_772/params/package_16.par', './CASE_090_772/params/package_47.par']
# Naturally sorted list: ['./CASE_090_772/params/package_2.par', './CASE_090_772/params/package_3.par', './CASE_090_772/params/package_4.par', './CASE_090_772/params/package_5.par', './CASE_090_772/params/package_6.par', './CASE_090_772/params/package_7.par', './CASE_090_772/params/package_8.par', './CASE_090_772/params/package_9.par', './CASE_090_772/params/package_10.par', './CASE_090_772/params/package_11.par', './CASE_090_772/params/package_12.par', './CASE_090_772/params/package_13.par', './CASE_090_772/params/package_14.par', './CASE_090_772/params/package_15.par', './CASE_090_772/params/package_16.par', './CASE_090_772/params/package_17.par', './CASE_090_772/params/package_18.par', './CASE_090_772/params/package_19.par', './CASE_090_772/params/package_20.par', './CASE_090_772/params/package_21.par', './CASE_090_772/params/package_22.par', './CASE_090_772/params/package_23.par', './CASE_090_772/params/package_24.par', './CASE_090_772/params/package_25.par', './CASE_090_772/params/package_26.par', './CASE_090_772/params/package_27.par', './CASE_090_772/params/package_28.par', './CASE_090_772/params/package_29.par', './CASE_090_772/params/package_30.par', './CASE_090_772/params/package_31.par', './CASE_090_772/params/package_32.par', './CASE_090_772/params/package_33.par', './CASE_090_772/params/package_34.par', './CASE_090_772/params/package_35.par', './CASE_090_772/params/package_36.par', './CASE_090_772/params/package_37.par', './CASE_090_772/params/package_38.par', './CASE_090_772/params/package_39.par', './CASE_090_772/params/package_40.par', './CASE_090_772/params/package_41.par', './CASE_090_772/params/package_42.par', './CASE_090_772/params/package_43.par', './CASE_090_772/params/package_44.par', './CASE_090_772/params/package_45.par', './CASE_090_772/params/package_46.par', './CASE_090_772/params/package_47.par', './CASE_090_772/params/package_48.par', './CASE_090_772/params/package_49.par', './CASE_090_772/params/package_50.par']
# clean = 4 0.731156 -0.681839 -0.022530 0.017228
#
# ['4', '0.731156', '-0.681839', '-0.022530', '0.017228']
# 0.731156x + -0.681839y + -0.02253z + 0.017228 = 0
# Point normal form: -0.02356268703258949 0.0 0.0 -0.731156 0.681839 0.02253
# clean = 4 0.748814 -0.662040 -0.031310 0.012778
#
# ['4', '0.748814', '-0.662040', '-0.031310', '0.012778']
# 0.748814x + -0.66204y + -0.03131z + 0.012778 = 0
# Point normal form: -0.017064317707735165 0.0 0.0 -0.748814 0.66204 0.03131
# clean = 4 0.766933 -0.640703 -0.036251 0.010707
#
# ['4', '0.766933', '-0.640703', '-0.036251', '0.010707']
# 0.766933x + -0.640703y + -0.036251z + 0.010707 = 0
# Point normal form: -0.01396080231258793 0.0 0.0 -0.766933 0.640703 0.036251
# clean = 4 0.785782 -0.617268 -0.039076 0.013069
#
# ['4', '0.785782', '-0.617268', '-0.039076', '0.013069']
# 0.785782x + -0.617268y + -0.039076z + 0.013069 = 0
# Point normal form: -0.016631839365116537 0.0 0.0 -0.785782 0.617268 0.039076
# clean = 4 0.803204 -0.594315 -0.040655 0.010577
#
# ['4', '0.803204', '-0.594315', '-0.040655', '0.010577']
# 0.803204x + -0.594315y + -0.040655z + 0.010577 = 0
# Point normal form: -0.013168510116981488 0.0 0.0 -0.803204 0.594315 0.040655
# clean = 4 0.820933 -0.569503 -0.041655 0.011760
#
# ['4', '0.820933', '-0.569503', '-0.041655', '0.011760']
# 0.820933x + -0.569503y + -0.041655z + 0.01176 = 0
# Point normal form: -0.014325164172959303 0.0 0.0 -0.820933 0.569503 0.041655
# clean = 4 0.837180 -0.545283 -0.042371 0.008202
#
# ['4', '0.837180', '-0.545283', '-0.042371', '0.008202']
# 0.83718x + -0.545283y + -0.042371z + 0.008202 = 0
# Point normal form: -0.00979717623450154 0.0 0.0 -0.83718 0.545283 0.042371
# clean = 4 0.852689 -0.520660 -0.042824 0.003746
#
# ['4', '0.852689', '-0.520660', '-0.042824', '0.003746']
# 0.852689x + -0.52066y + -0.042824z + 0.003746 = 0
# Point normal form: -0.004393160929717635 0.0 0.0 -0.852689 0.52066 0.042824
# clean = 4 0.868497 -0.493828 -0.042978 0.004389
#
# ['4', '0.868497', '-0.493828', '-0.042978', '0.004389']
# 0.868497x + -0.493828y + -0.042978z + 0.004389 = 0
# Point normal form: -0.005053558043378388 0.0 0.0 -0.868497 0.493828 0.042978
# clean = 4 0.882969 -0.467465 -0.042912 0.001475
#
# ['4', '0.882969', '-0.467465', '-0.042912', '0.001475']
# 0.882969x + -0.467465y + -0.042912z + 0.001475 = 0
# Point normal form: -0.00167050032334091 0.0 0.0 -0.882969 0.467465 0.042912
# clean = 4 0.897720 -0.438474 -0.042886 0.005152
#
# ['4', '0.897720', '-0.438474', '-0.042886', '0.005152']
# 0.89772x + -0.438474y + -0.042886z + 0.005152 = 0
# Point normal form: -0.0057389832018892315 0.0 0.0 -0.89772 0.438474 0.042886
# clean = 4 0.911623 -0.408788 -0.042852 0.009287
#
# ['4', '0.911623', '-0.408788', '-0.042852', '0.009287']
# 0.911623x + -0.408788y + -0.042852z + 0.009287 = 0
# Point normal form: -0.01018732524300067 0.0 0.0 -0.911623 0.408788 0.042852
# clean = 4 0.923863 -0.380323 -0.042802 0.008158
#
# ['4', '0.923863', '-0.380323', '-0.042802', '0.008158']
# 0.923863x + -0.380323y + -0.042802z + 0.008158 = 0
# Point normal form: -0.008830313585455853 0.0 0.0 -0.923863 0.380323 0.042802
# clean = 4 0.935837 -0.349831 -0.042749 0.011942
#
# ['4', '0.935837', '-0.349831', '-0.042749', '0.011942']
# 0.935837x + -0.349831y + -0.042749z + 0.011942 = 0
# Point normal form: -0.012760769236523027 0.0 0.0 -0.935837 0.349831 0.042749
# clean = 4 0.946714 -0.319240 -0.042648 0.014816
#
# ['4', '0.946714', '-0.319240', '-0.042648', '0.014816']
# 0.946714x + -0.31924y + -0.042648z + 0.014816 = 0
# Point normal form: -0.01564992172926565 0.0 0.0 -0.946714 0.31924 0.042648
# clean = 4 0.955881 -0.290664 -0.042488 0.010672
#
# ['4', '0.955881', '-0.290664', '-0.042488', '0.010672']
# 0.955881x + -0.290664y + -0.042488z + 0.010672 = 0
# Point normal form: -0.011164569648313962 0.0 0.0 -0.955881 0.290664 0.042488
# clean = 4 0.964566 -0.260393 -0.042528 0.010772
#
# ['4', '0.964566', '-0.260393', '-0.042528', '0.010772']
# 0.964566x + -0.260393y + -0.042528z + 0.010772 = 0
# Point normal form: -0.011167716879923198 0.0 0.0 -0.964566 0.260393 0.042528
# clean = 4 0.971977 -0.231150 -0.042796 0.007160
#
# ['4', '0.971977', '-0.231150', '-0.042796', '0.007160']
# 0.971977x + -0.23115y + -0.042796z + 0.00716 = 0
# Point normal form: -0.007366429452548774 0.0 0.0 -0.971977 0.23115 0.042796
# clean = 4 0.978438 -0.202024 -0.042951 0.002683
#
# ['4', '0.978438', '-0.202024', '-0.042951', '0.002683']
# 0.978438x + -0.202024y + -0.042951z + 0.002683 = 0
# Point normal form: -0.002742125714659488 0.0 0.0 -0.978438 0.202024 0.042951
# clean = 4 0.984279 -0.171324 -0.042940 0.002203
#
# ['4', '0.984279', '-0.171324', '-0.042940', '0.002203']
# 0.984279x + -0.171324y + -0.04294z + 0.002203 = 0
# Point normal form: -0.002238186530445128 0.0 0.0 -0.984279 0.171324 0.04294
# clean = 4 0.988949 -0.141959 -0.042755 -0.002597
#
# ['4', '0.988949', '-0.141959', '-0.042755', '-0.002597']
# 0.988949x + -0.141959y + -0.042755z + -0.002597 = 0
# Point normal form: 0.0026260201486628734 0.0 0.0 -0.988949 0.141959 0.042755
# clean = 4 0.993033 -0.109862 -0.042612 0.000021
#
# ['4', '0.993033', '-0.109862', '-0.042612', '0.000021']
# 0.993033x + -0.109862y + -0.042612z + 2.1e-05 = 0
# Point normal form: -2.1147333472301523e-05 0.0 0.0 -0.993033 0.109862 0.042612
# clean = 4 0.996103 -0.077282 -0.042508 0.003674
#
# ['4', '0.996103', '-0.077282', '-0.042508', '0.003674']
# 0.996103x + -0.077282y + -0.042508z + 0.003674 = 0
# Point normal form: -0.0036883735918875863 0.0 0.0 -0.996103 0.077282 0.042508
# clean = 4 0.998025 -0.046304 -0.042443 0.002529
#
# ['4', '0.998025', '-0.046304', '-0.042443', '0.002529']
# 0.998025x + -0.046304y + -0.042443z + 0.002529 = 0
# Point normal form: -0.002534004659201924 0.0 0.0 -0.998025 0.046304 0.042443
# clean = 4 0.999010 -0.013373 -0.042430 0.006789
#
# ['4', '0.999010', '-0.013373', '-0.042430', '0.006789']
# 0.99901x + -0.013373y + -0.04243z + 0.006789 = 0
# Point normal form: -0.006795727770492788 0.0 0.0 -0.99901 0.013373 0.04243
# clean = 4 0.998910 0.019478 -0.042423 0.010771
#
# ['4', '0.998910', '0.019478', '-0.042423', '0.010771']
# 0.99891x + 0.019478y + -0.042423z + 0.010771 = 0
# Point normal form: -0.010782753200989079 0.0 0.0 -0.99891 -0.019478 0.042423
# clean = 4 0.997837 0.050226 -0.042409 0.008824
#
# ['4', '0.997837', '0.050226', '-0.042409', '0.008824']
# 0.997837x + 0.050226y + -0.042409z + 0.008824 = 0
# Point normal form: -0.008843127685183052 0.0 0.0 -0.997837 -0.050226 0.042409
# clean = 4 0.995703 0.082336 -0.042387 0.010875
#
# ['4', '0.995703', '0.082336', '-0.042387', '0.010875']
# 0.995703x + 0.082336y + -0.042387z + 0.010875 = 0
# Point normal form: -0.010921931539826634 0.0 0.0 -0.995703 -0.082336 0.042387
# clean = 4 0.992649 0.113434 -0.042202 0.010228
#
# ['4', '0.992649', '0.113434', '-0.042202', '0.010228']
# 0.992649x + 0.113434y + -0.042202z + 0.010228 = 0
# Point normal form: -0.01030374281342146 0.0 0.0 -0.992649 -0.113434 0.042202
# clean = 4 0.988845 0.142712 -0.042653 0.004846
#
# ['4', '0.988845', '0.142712', '-0.042653', '0.004846']
# 0.988845x + 0.142712y + -0.042653z + 0.004846 = 0
# Point normal form: -0.004900666939712492 0.0 0.0 -0.988845 -0.142712 0.042653
# clean = 4 0.983918 0.173369 -0.042997 0.003811
#
# ['4', '0.983918', '0.173369', '-0.042997', '0.003811']
# 0.983918x + 0.173369y + -0.042997z + 0.003811 = 0
# Point normal form: -0.003873290253862619 0.0 0.0 -0.983918 -0.173369 0.042997
# clean = 4 0.978345 0.202389 -0.043355 -0.001463
#
# ['4', '0.978345', '0.202389', '-0.043355', '-0.001463']
# 0.978345x + 0.202389y + -0.043355z + -0.001463 = 0
# Point normal form: 0.0014953825082154046 0.0 0.0 -0.978345 -0.202389 0.043355
# clean = 4 -0.971603 -0.232622 0.043294 0.002703
#
# ['4', '-0.971603', '-0.232622', '0.043294', '0.002703']
# -0.971603x + -0.232622y + 0.043294z + 0.002703 = 0
# Point normal form: 0.002782000467269039 0.0 0.0 -0.971603 -0.232622 0.043294
# clean = 4 -0.963635 -0.263692 0.043285 0.000869
#
# ['4', '-0.963635', '-0.263692', '0.043285', '0.000869']
# -0.963635x + -0.263692y + 0.043285z + 0.000869 = 0
# Point normal form: 0.00090179372895339 0.0 0.0 -0.963635 -0.263692 0.043285
# clean = 4 -0.955073 -0.293201 0.043227 0.002937
#
# ['4', '-0.955073', '-0.293201', '0.043227', '0.002937']
# -0.955073x + -0.293201y + 0.043227z + 0.002937 = 0
# Point normal form: 0.0030751576057536966 0.0 0.0 -0.955073 -0.293201 0.043227
# clean = 4 -0.944910 -0.324464 0.043216 -0.001003
#
# ['4', '-0.944910', '-0.324464', '0.043216', '-0.001003']
# -0.94491x + -0.324464y + 0.043216z + -0.001003 = 0
# Point normal form: -0.00106147675439989 0.0 0.0 -0.94491 -0.324464 0.043216
# clean = 4 -0.933675 -0.355509 0.043187 -0.005196
#
# ['4', '-0.933675', '-0.355509', '0.043187', '-0.005196']
# -0.933675x + -0.355509y + 0.043187z + -0.005196 = 0
# Point normal form: -0.005565105630974375 0.0 0.0 -0.933675 -0.355509 0.043187
# clean = 4 -0.922110 -0.384518 0.043113 -0.004090
#
# ['4', '-0.922110', '-0.384518', '0.043113', '-0.004090']
# -0.92211x + -0.384518y + 0.043113z + -0.00409 = 0
# Point normal form: -0.004435479498107601 0.0 0.0 -0.92211 -0.384518 0.043113
# clean = 4 -0.908862 -0.414871 0.043026 -0.007993
#
# ['4', '-0.908862', '-0.414871', '0.043026', '-0.007993']
# -0.908862x + -0.414871y + 0.043026z + -0.007993 = 0
# Point normal form: -0.008794514458740712 0.0 0.0 -0.908862 -0.414871 0.043026
# clean = 4 -0.894610 -0.444788 0.042859 -0.011414
#
# ['4', '-0.894610', '-0.444788', '0.042859', '-0.011414']
# -0.89461x + -0.444788y + 0.042859z + -0.011414 = 0
# Point normal form: -0.012758632253160596 0.0 0.0 -0.89461 -0.444788 0.042859
# clean = 4 -0.880233 -0.472625 0.042604 -0.008952
#
# ['4', '-0.880233', '-0.472625', '0.042604', '-0.008952']
# -0.880233x + -0.472625y + 0.042604z + -0.008952 = 0
# Point normal form: -0.010170034524949644 0.0 0.0 -0.880233 -0.472625 0.042604
# clean = 4 -0.864024 -0.501675 0.042241 -0.010945
#
# ['4', '-0.864024', '-0.501675', '0.042241', '-0.010945']
# -0.864024x + -0.501675y + 0.042241z + -0.010945 = 0
# Point normal form: -0.0126674721998463 0.0 0.0 -0.864024 -0.501675 0.042241
# clean = 4 -0.846800 -0.530281 0.041613 -0.011951
#
# ['4', '-0.846800', '-0.530281', '0.041613', '-0.011951']
# -0.8468x + -0.530281y + 0.041613z + -0.011951 = 0
# Point normal form: -0.014113131790269249 0.0 0.0 -0.8468 -0.530281 0.041613
# clean = 4 -0.829539 -0.556971 0.040606 -0.006762
#
# ['4', '-0.829539', '-0.556971', '0.040606', '-0.006762']
# -0.829539x + -0.556971y + 0.040606z + -0.006762 = 0
# Point normal form: -0.008151515480284833 0.0 0.0 -0.829539 -0.556971 0.040606
# clean = 4 0.810142 0.584943 -0.038880 0.006048
#
# ['4', '0.810142', '0.584943', '-0.038880', '0.006048']
# 0.810142x + 0.584943y + -0.03888z + 0.006048 = 0
# Point normal form: -0.007465357924906992 0.0 0.0 -0.810142 -0.584943 0.03888
# clean = 4 0.789444 0.612778 -0.035803 0.005102
#
# ['4', '0.789444', '0.612778', '-0.035803', '0.005102']
# 0.789444x + 0.612778y + -0.035803z + 0.005102 = 0
# Point normal form: -0.006462776333723481 0.0 0.0 -0.789444 -0.612778 0.035803
# clean = 4 0.768334 0.639330 -0.030337 -0.000069
#
# ['4', '0.768334', '0.639330', '-0.030337', '-0.000069']
# 0.768334x + 0.63933y + -0.030337z + -6.9e-05 = 0
# Point normal form: 8.980469431262967e-05 0.0 0.0 -0.768334 -0.63933 0.030337
# clean = 4 0.743894 0.667974 -0.020799 0.003505
#
# ['4', '0.743894', '0.667974', '-0.020799', '0.003505']
# 0.743894x + 0.667974y + -0.020799z + 0.003505 = 0
# Point normal form: -0.004711692794941214 0.0 0.0 -0.743894 -0.667974 0.020799
# clean = 4 0.718386 0.695627 -0.005018 0.005915
#
# ['4', '0.718386', '0.695627', '-0.005018', '0.005915']
# 0.718386x + 0.695627y + -0.005018z + 0.005915 = 0
# Point normal form: -0.00823373506722013 0.0 0.0 -0.718386 -0.695627 0.005018
